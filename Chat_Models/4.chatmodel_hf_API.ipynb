# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation"
)

# %%
model = ChatHuggingFace(llm=llm)
result = model.invoke("What is the capital of Pakistan")
print(result.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 model = ChatHuggingFace(llm=llm)
# ----> 2 result = model.invoke("What is the capital of Pakistan")
#       3 print(result.content)
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)
#     447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1185, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1176 @override
#    1177 def generate_prompt(
#    1178     self,
#    (...)
#    1182     **kwargs: Any,
#    1183 ) -> LLMResult:
#    1184     prompt_messages = [p.to_messages() for p in prompts]
# -> 1185     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:995, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     992 for i, m in enumerate(input_messages):
#     993     try:
#     994         results.append(
# --> 995             self._generate_with_cache(
#     996                 m,
#     997                 stop=stop,
#     998                 run_manager=run_managers[i] if run_managers else None,
#     999                 **kwargs,
#    1000             )
#    1001         )
#    1002     except BaseException as e:
#    1003         if run_managers:
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1297, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1295     result = generate_from_stream(iter(chunks))
#    1296 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1297     result = self._generate(
#    1298         messages, stop=stop, run_manager=run_manager, **kwargs
#    1299     )
#    1300 else:
#    1301     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Langchain\venv\lib\site-packages\langchain_huggingface\chat_models\huggingface.py:750, in ChatHuggingFace._generate(self, messages, stop, run_manager, stream, **kwargs)
#     743     message_dicts, params = self._create_message_dicts(messages, stop)
#     744     params = {
#     745         "stop": stop,
#     746         **params,
#     747         **({"stream": stream} if stream is not None else {}),
#     748         **kwargs,
#     749     }
# --> 750     answer = self.llm.client.chat_completion(messages=message_dicts, **params)
#     751     return self._create_chat_result(answer)
#     752 llm_input = self._to_chat_prompt(messages)
#
# File d:\Langchain\venv\lib\site-packages\huggingface_hub\inference\_client.py:922, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     900 # Prepare the payload
#     901 parameters = {
#     902     "model": payload_model,
#     903     "frequency_penalty": frequency_penalty,
#    (...)
#     920     **(extra_body or {}),
#     921 }
# --> 922 request_parameters = provider_helper.prepare_request(
#     923     inputs=messages,
#     924     parameters=parameters,
#     925     headers=self.headers,
#     926     model=model_id_or_url,
#     927     api_key=self.token,
#     928 )
#     929 data = self._inner_post(request_parameters, stream=stream)
#     931 if stream:
#
# File d:\Langchain\venv\lib\site-packages\huggingface_hub\inference\_providers\_common.py:93, in TaskProviderHelper.prepare_request(self, inputs, parameters, headers, model, api_key, extra_payload)
#      87 """
#      88 Prepare the request to be sent to the provider.
#      89
#      90 Each step (api_key, model, headers, url, payload) can be customized in subclasses.
#      91 """
#      92 # api_key from user, or local token, or raise error
# ---> 93 api_key = self._prepare_api_key(api_key)
#      95 # mapped model from HF model ID
#      96 provider_mapping_info = self._prepare_mapping_info(model)
#
# File d:\Langchain\venv\lib\site-packages\huggingface_hub\inference\_providers\_common.py:148, in TaskProviderHelper._prepare_api_key(self, api_key)
#     146     api_key = get_token()
#     147 if api_key is None:
# --> 148     raise ValueError(
#     149         f"You must provide an api_key to work with {self.provider} API or log in with `hf auth login`."
#     150     )
#     151 return api_key
#
# ValueError: You must provide an api_key to work with auto API or log in with `hf auth login`.
